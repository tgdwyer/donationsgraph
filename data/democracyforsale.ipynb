# %%
import pandas as pd

# Specify the file path
file_path = "democracyforsaleFY2022.csv"

# Load the CSV file into a dataframe
df = pd.read_csv(file_path)

# Display the dataframe
df
# Out:
#         FY                    Received From       Value Party (specific)  \
# 0     2022               Mineralogy Pty Ltd  50,000,000     Palmer's UAP
# 1     2022               Mineralogy Pty Ltd  30,200,000     Palmer's UAP
# 2     2022  Australian Electoral Commission  25,556,710      Labor (Fed)
# 3     2022               Mineralogy Pty Ltd  10,000,000     Palmer's UAP
# 4     2022               Mineralogy Pty Ltd   6,500,000     Palmer's UAP
# ...    ...                              ...         ...              ...
# 3383  2022    Minerals Council of Australia         300      Labor (Fed)
# 3384  2022                    APPEA Limited         300       Labor (NT)
# 3385  2022                  Holding Redlich         198      Labor (QLD)
# 3386  2022                  Gunning, Robert          65   Liberals (ACT)
# 3387  2022                  Gunning, Robert          20   Liberals (ACT)
#
#             Party Group       Receipt type                       Category  \
# ...

# %%
grouped_df = df.groupby(["Received From", "Party Group"])["Value"].sum()
grouped_df
# Out:
# Received From              Party Group
# 141 Abbott Street Pty Ltd  Labor                         2,000
# 1973 Foundation Pty Ltd    Labor                217,297100,000
# 89 Pirie Street Pty Ltd    Liberal/Nationals            25,000
# AARNet                     Labor                         1,800
# ACCIONA Energia            Labor                         1,200
#                                                      ...
# Zashvin Pty Ltd            Liberal/Nationals            20,000
# Zeljana Zubac              Labor                    1,0001,000
# Zetaris Pty Ltd            Labor                         1,800
# mr michael siddle          Liberal/Nationals           250,000
# u-Communications Pty Ltd   Labor                         2,000
# Name: Value, Length: 1495, dtype: object
